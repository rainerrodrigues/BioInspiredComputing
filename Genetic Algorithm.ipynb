# %%
import random
import numpy as np

class GeneticAlgorithm:
    def __init__(self, fitness_function, num_dimensions, population_size=50, crossover_rate=0.8, mutation_rate=0.1, num_iterations=1000):
        self.fitness_func = fitness_function
        self.num_dimensions = num_dimensions
        self.population_size = population_size
        self.crossover_rate = crossover_rate
        self.mutation_rate = mutation_rate
        self.num_iterations = num_iterations
        self.population = None
        self.fitnesses = None
        self.best_solution = None
        self.best_fitness = np.inf
        
    def init_population(self):
        self.population = np.random.uniform(low=-5.12, high=5.12, size=(self.population_size, self.num_dimensions))
        self.fitnesses = np.zeros(self.population_size)
        
    def selection(self):
        parents = np.zeros_like(self.population)
        for i in range(self.population_size):
            # Tournament selection: choose 2 random individuals and keep the best one
            a, b = random.sample(range(self.population_size), 2)
            if self.fitnesses[a] < self.fitnesses[b]:
                parents[i] = self.population[a]
            else:
                parents[i] = self.population[b]
        return parents
    
    def crossover(self, parents):
        offsprings = np.zeros_like(parents)
        for i in range(0, self.population_size, 2):
            if random.random() < self.crossover_rate:
                # Single-point crossover
                index = random.randint(1, self.num_dimensions-1)
                offsprings[i] = np.concatenate((parents[i][:index], parents[i+1][index:]))
                offsprings[i+1] = np.concatenate((parents[i+1][:index], parents[i][index:]))
            else:
                offsprings[i] = parents[i]
                offsprings[i+1] = parents[i+1]
        return offsprings
    
    def mutation(self, offsprings):
        mutants = np.zeros_like(offsprings)
        for i in range(self.population_size):
            for j in range(self.num_dimensions):
                if random.random() < self.mutation_rate:
                    mutants[i][j] = np.random.uniform(low=-5.12, high=5.12)
                else:
                    mutants[i][j] = offsprings[i][j]
        return mutants
    
    def run(self):
        self.init_population()
        for i in range(self.num_iterations):
            self.fitnesses = np.array([self.fitness_func(x) for x in self.population])
            min_index = np.argmin(self.fitnesses)
            if self.fitnesses[min_index] < self.best_fitness:
                self.best_fitness = self.fitnesses[min_index]
                self.best_solution = self.population[min_index]
            parents = self.selection()
            offsprings = self.crossover(parents)
            mutants = self.mutation(offsprings)
            self.population = mutants
            print(f"Iteration {i}: Best fitness = {self.best_fitness:.3f}")
        return self.best_solution, self.best_fitness

# %%
# Define the fitness function
def sphere(x):
    return sum(x**2)

# Create an instance of the genetic algorithm
ga = GeneticAlgorithm(fitness_function=sphere, num_dimensions=10, population_size=50, mutation_rate=0.1, num_iterations=100)

# Run the algorithm
best_solution,best_fitness = ga.run()

print(f"Best solution: {best_solution}")
print(f"Best fitness: {best_fitness}")
# Out:
# Iteration 0: Best fitness = 20.609
# Iteration 1: Best fitness = 20.609
# Iteration 2: Best fitness = 20.609
# Iteration 3: Best fitness = 20.609
# Iteration 4: Best fitness = 20.609
# Iteration 5: Best fitness = 15.234
# Iteration 6: Best fitness = 15.234
# Iteration 7: Best fitness = 15.234
# Iteration 8: Best fitness = 15.234
# Iteration 9: Best fitness = 15.234
# Iteration 10: Best fitness = 12.494
# Iteration 11: Best fitness = 12.494
# Iteration 12: Best fitness = 12.494
# Iteration 13: Best fitness = 10.009
# Iteration 14: Best fitness = 9.556
# Iteration 15: Best fitness = 9.556
# Iteration 16: Best fitness = 7.390
# Iteration 17: Best fitness = 7.390
# Iteration 18: Best fitness = 7.390
# Iteration 19: Best fitness = 7.390
# Iteration 20: Best fitness = 6.417
# Iteration 21: Best fitness = 6.417
# Iteration 22: Best fitness = 5.533
# Iteration 23: Best fitness = 5.326
# Iteration 24: Best fitness = 5.326
# Iteration 25: Best fitness = 3.094
# Iteration 26: Best fitness = 3.094
# Iteration 27: Best fitness = 2.079
# Iteration 28: Best fitness = 2.079
# Iteration 29: Best fitness = 2.079
# Iteration 30: Best fitness = 2.079
# Iteration 31: Best fitness = 2.079
# Iteration 32: Best fitness = 2.079
# Iteration 33: Best fitness = 2.079
# Iteration 34: Best fitness = 2.079
# Iteration 35: Best fitness = 2.079
# Iteration 36: Best fitness = 2.079
# Iteration 37: Best fitness = 2.079
# Iteration 38: Best fitness = 2.079
# Iteration 39: Best fitness = 2.079
# Iteration 40: Best fitness = 2.079
# Iteration 41: Best fitness = 2.079
# Iteration 42: Best fitness = 2.079
# Iteration 43: Best fitness = 2.079
# Iteration 44: Best fitness = 2.079
# Iteration 45: Best fitness = 2.079
# Iteration 46: Best fitness = 2.079
# Iteration 47: Best fitness = 2.079
# Iteration 48: Best fitness = 2.079
# Iteration 49: Best fitness = 2.079
# Iteration 50: Best fitness = 2.079
# Iteration 51: Best fitness = 2.079
# Iteration 52: Best fitness = 2.079
# Iteration 53: Best fitness = 2.079
# Iteration 54: Best fitness = 2.079
# Iteration 55: Best fitness = 2.079
# Iteration 56: Best fitness = 2.079
# Iteration 57: Best fitness = 2.079
# Iteration 58: Best fitness = 2.079
# Iteration 59: Best fitness = 2.079
# Iteration 60: Best fitness = 2.079
# Iteration 61: Best fitness = 2.079
# Iteration 62: Best fitness = 2.079
# Iteration 63: Best fitness = 2.079
# Iteration 64: Best fitness = 2.079
# Iteration 65: Best fitness = 2.079
# Iteration 66: Best fitness = 2.079
# Iteration 67: Best fitness = 2.079
# Iteration 68: Best fitness = 2.079
# Iteration 69: Best fitness = 2.079
# Iteration 70: Best fitness = 2.079
# Iteration 71: Best fitness = 2.079
# Iteration 72: Best fitness = 2.079
# Iteration 73: Best fitness = 2.079
# Iteration 74: Best fitness = 2.079
# Iteration 75: Best fitness = 2.079
# Iteration 76: Best fitness = 2.079
# Iteration 77: Best fitness = 2.079
# Iteration 78: Best fitness = 2.079
# Iteration 79: Best fitness = 2.079
# Iteration 80: Best fitness = 2.079
# Iteration 81: Best fitness = 2.079
# Iteration 82: Best fitness = 2.079
# Iteration 83: Best fitness = 2.079
# Iteration 84: Best fitness = 2.079
# Iteration 85: Best fitness = 2.079
# Iteration 86: Best fitness = 2.079
# Iteration 87: Best fitness = 2.079
# Iteration 88: Best fitness = 2.079
# Iteration 89: Best fitness = 2.079
# Iteration 90: Best fitness = 2.079
# Iteration 91: Best fitness = 2.079
# Iteration 92: Best fitness = 2.079
# Iteration 93: Best fitness = 2.079
# Iteration 94: Best fitness = 2.079
# Iteration 95: Best fitness = 2.079
# Iteration 96: Best fitness = 2.079
# Iteration 97: Best fitness = 2.079
# Iteration 98: Best fitness = 2.079
# Iteration 99: Best fitness = 2.079
# Best solution: [-0.36511187  0.50473247  0.2104815   0.41377902  0.32557802  0.84848103
#   0.27492393  0.47527544 -0.27576547 -0.52158659]
# Best fitness: 2.079067262984443
