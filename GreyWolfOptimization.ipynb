# %%
import numpy as np

class GreyWolfOptimizer:
    def __init__(self, fitness_function, num_dimensions, num_wolves=50, num_iterations=100, a=2.0):
        self.fitness_function = fitness_function
        self.num_dimensions = num_dimensions
        self.num_wolves = num_wolves
        self.num_iterations = num_iterations
        self.a = a
        self.iteration = 0
        self.best_fitness = np.inf
        self.best_position = np.zeros(num_dimensions)
        self.positions = np.zeros((num_wolves, num_dimensions))
        self.fitnesses = np.zeros(num_wolves)

    def init_wolves(self):
        self.positions = np.random.uniform(-10.0, 10.0, size=(self.num_wolves, self.num_dimensions))
        self.fitnesses = np.array([self.fitness_function(x) for x in self.positions])
        self.update_best()

    def update_wolves(self):
        a = 2.0 - 2.0 * (self.iteration / self.num_iterations)
        for j in range(self.num_wolves):
            r1 = np.random.uniform()
            r2 = np.random.uniform()
            A = 2.0 * a * r1 - a
            C = 2.0 * r2
            D = np.abs(C * self.best_position - self.positions[j])
            new_position = self.best_position - A * D
            new_position = np.clip(new_position, -10.0, 10.0)
            new_fitness = self.fitness_function(new_position)
            if new_fitness < self.fitnesses[j]:
                self.fitnesses[j] = new_fitness
                self.positions[j] = new_position
        self.update_best()
        self.iteration += 1

    def update_best(self):
        best_index = np.argmin(self.fitnesses)
        if self.fitnesses[best_index] < self.best_fitness:
            self.best_fitness = self.fitnesses[best_index]
            self.best_position = self.positions[best_index]

    def run(self):
        self.init_wolves()
        for i in range(self.num_iterations):
            self.update_wolves()
            print(f"Iteration {i}: Best fitness = {self.best_fitness:.3f}")
        return self.best_position, self.best_fitness

# %%
def fitness_function(x):
    return np.sum(x**2)

gwo = GreyWolfOptimizer(fitness_function, num_dimensions=10, num_wolves=50, num_iterations=100, a=2.0)
best_positions,best_fitnesses = gwo.run()

print(f"Best solutions: {best_positions}")
print(f"Best fitnesses: {best_fitnesses}")
# Out:
# Iteration 0: Best fitness = 112.709
# Iteration 1: Best fitness = 91.026
# Iteration 2: Best fitness = 30.111
# Iteration 3: Best fitness = 21.786
# Iteration 4: Best fitness = 11.595
# Iteration 5: Best fitness = 10.117
# Iteration 6: Best fitness = 9.874
# Iteration 7: Best fitness = 6.431
# Iteration 8: Best fitness = 3.146
# Iteration 9: Best fitness = 2.303
# Iteration 10: Best fitness = 1.449
# Iteration 11: Best fitness = 0.774
# Iteration 12: Best fitness = 0.256
# Iteration 13: Best fitness = 0.193
# Iteration 14: Best fitness = 0.129
# Iteration 15: Best fitness = 0.002
# Iteration 16: Best fitness = 0.001
# Iteration 17: Best fitness = 0.001
# Iteration 18: Best fitness = 0.001
# Iteration 19: Best fitness = 0.000
# Iteration 20: Best fitness = 0.000
# Iteration 21: Best fitness = 0.000
# Iteration 22: Best fitness = 0.000
# Iteration 23: Best fitness = 0.000
# Iteration 24: Best fitness = 0.000
# Iteration 25: Best fitness = 0.000
# Iteration 26: Best fitness = 0.000
# Iteration 27: Best fitness = 0.000
# Iteration 28: Best fitness = 0.000
# Iteration 29: Best fitness = 0.000
# Iteration 30: Best fitness = 0.000
# Iteration 31: Best fitness = 0.000
# Iteration 32: Best fitness = 0.000
# Iteration 33: Best fitness = 0.000
# Iteration 34: Best fitness = 0.000
# Iteration 35: Best fitness = 0.000
# Iteration 36: Best fitness = 0.000
# Iteration 37: Best fitness = 0.000
# Iteration 38: Best fitness = 0.000
# Iteration 39: Best fitness = 0.000
# Iteration 40: Best fitness = 0.000
# Iteration 41: Best fitness = 0.000
# Iteration 42: Best fitness = 0.000
# Iteration 43: Best fitness = 0.000
# Iteration 44: Best fitness = 0.000
# Iteration 45: Best fitness = 0.000
# Iteration 46: Best fitness = 0.000
# Iteration 47: Best fitness = 0.000
# Iteration 48: Best fitness = 0.000
# Iteration 49: Best fitness = 0.000
# Iteration 50: Best fitness = 0.000
# Iteration 51: Best fitness = 0.000
# Iteration 52: Best fitness = 0.000
# Iteration 53: Best fitness = 0.000
# Iteration 54: Best fitness = 0.000
# Iteration 55: Best fitness = 0.000
# Iteration 56: Best fitness = 0.000
# Iteration 57: Best fitness = 0.000
# Iteration 58: Best fitness = 0.000
# Iteration 59: Best fitness = 0.000
# Iteration 60: Best fitness = 0.000
# Iteration 61: Best fitness = 0.000
# Iteration 62: Best fitness = 0.000
# Iteration 63: Best fitness = 0.000
# Iteration 64: Best fitness = 0.000
# Iteration 65: Best fitness = 0.000
# Iteration 66: Best fitness = 0.000
# Iteration 67: Best fitness = 0.000
# Iteration 68: Best fitness = 0.000
# Iteration 69: Best fitness = 0.000
# Iteration 70: Best fitness = 0.000
# Iteration 71: Best fitness = 0.000
# Iteration 72: Best fitness = 0.000
# Iteration 73: Best fitness = 0.000
# Iteration 74: Best fitness = 0.000
# Iteration 75: Best fitness = 0.000
# Iteration 76: Best fitness = 0.000
# Iteration 77: Best fitness = 0.000
# Iteration 78: Best fitness = 0.000
# Iteration 79: Best fitness = 0.000
# Iteration 80: Best fitness = 0.000
# Iteration 81: Best fitness = 0.000
# Iteration 82: Best fitness = 0.000
# Iteration 83: Best fitness = 0.000
# Iteration 84: Best fitness = 0.000
# Iteration 85: Best fitness = 0.000
# Iteration 86: Best fitness = 0.000
# Iteration 87: Best fitness = 0.000
# Iteration 88: Best fitness = 0.000
# Iteration 89: Best fitness = 0.000
# Iteration 90: Best fitness = 0.000
# Iteration 91: Best fitness = 0.000
# Iteration 92: Best fitness = 0.000
# Iteration 93: Best fitness = 0.000
# Iteration 94: Best fitness = 0.000
# Iteration 95: Best fitness = 0.000
# Iteration 96: Best fitness = 0.000
# Iteration 97: Best fitness = 0.000
# Iteration 98: Best fitness = 0.000
# Iteration 99: Best fitness = 0.000
# Best solutions: [-8.65760470e-13 -1.32063101e-13 -3.50091097e-13 -3.07303008e-13
#  -1.16236908e-13  3.66846332e-13 -9.21743299e-14  1.22118166e-12
#  -5.09314568e-13 -6.62422671e-13]
# Best fitnesses: 3.3300538930544965e-24
